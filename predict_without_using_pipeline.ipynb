# %%
import pickle
import numpy as np

ohe_sex = pickle.load(open("/content/ohe_sex.pkl",'rb'))
ohe_embarked = pickle.load(open("/content/ohe_embarked.pkl",'rb'))
dtc = pickle.load(open("/content/dtc.pkl",'rb'))

#Assume User Input

test_input = np.array([[2,'male',26.0,1,0,13.0,'S']])
test_input
# Out:
# array([['2', 'male', '26.0', '1', '0', '13.0', 'S']], dtype='<U32')

# %%
# !wget https://raw.githubusercontent.com/Nadia-Nasrin-Mukti/ML-projects/main/ohe_sex.pkl
# !wget https://raw.githubusercontent.com/Nadia-Nasrin-Mukti/ML-projects/main/ohe_embarked.pkl
# !wget https://raw.githubusercontent.com/Nadia-Nasrin-Mukti/ML-projects/main/dtc.pkl
# Out:
# --2026-02-04 11:19:19--  https://raw.githubusercontent.com/Nadia-Nasrin-Mukti/ML-projects/main/ohe_sex.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593 [application/octet-stream]
# Saving to: ‘ohe_sex.pkl.6’
#
# ohe_sex.pkl.6       100%[===================>]     593  --.-KB/s    in 0.001s
#
# 2026-02-04 11:19:19 (1.04 MB/s) - ‘ohe_sex.pkl.6’ saved [593/593]
#
# --2026-02-04 11:19:19--  https://raw.githubusercontent.com/Nadia-Nasrin-Mukti/ML-projects/main/ohe_embarked.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))
test_input_age = test_input[:,2].reshape(1,1)

test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_sex,test_input_embarked,test_input_age),axis =1 )


test_input_transformed.shape
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# (1, 10)
